# %% [markdown]
# # LAB 4 - COMPARING REGRESSION MODELS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression

# %matplotlib inline

pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore")

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# ### First of all, I will clean the dataset according to the criteria defined in the previous labs.

# %%
# First of all, we will remove duplicated rows, in case there are any. 
customer_df = customer_df.drop_duplicates()

# %%
# Standardizing header names
cols = []
for i in range(len(customer_df.columns)):
    cols.append(customer_df.columns[i].lower().replace(' ', '_'))
customer_df.columns = cols

# %%
# Converting effective_to_date into datetime
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], errors='coerce')

# %%
# Function to split continuous and discrete variables. Done in lab1 but it is in a different Jupyter Notebook.

def cont_disc(DataFrame):
    continuous = []
    discrete = []

    threshold = customer_df.shape[0] * 0.03 

    for x in customer_df.columns:    # df.index for rows
        if customer_df[x].nunique() < threshold:
            discrete.append(x)
        else:
            continuous.append(x)
    return discrete, continuous

discrete, continuous = cont_disc(customer_df)

# %%
discrete_df = customer_df[discrete]
continuous_df = customer_df[continuous]
display(discrete_df.head())
display(continuous_df.head())
# Out:
#         state response  coverage education effective_to_date employmentstatus  \
# 0  Washington       No     Basic  Bachelor        2011-02-24         Employed
# 1     Arizona       No  Extended  Bachelor        2011-01-31       Unemployed
# 2      Nevada       No   Premium  Bachelor        2011-02-19         Employed
# 3  California       No     Basic  Bachelor        2011-01-20       Unemployed
# 4  Washington       No     Basic  Bachelor        2011-02-03         Employed
#
#   gender location_code marital_status  monthly_premium_auto  \
# 0      F      Suburban        Married                    69
# 1      F      Suburban         Single                    94
# 2      F      Suburban        Married                   108
# 3      M      Suburban        Married                   106
# 4      M         Rural         Single                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies     policy_type  \
# 0                          0                   1  Corporate Auto
# 1                          0                   8   Personal Auto
# 2                          0                   2   Personal Auto
# 3                          0                   7  Corporate Auto
# 4                          0                   1   Personal Auto
#
#          policy renew_offer_type sales_channel  vehicle_class vehicle_size
# 0  Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1   Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2   Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3  Corporate L2           Offer1   Call Center            SUV      Medsize
# 4   Personal L1           Offer1         Agent  Four-Door Car      Medsize
#   customer  customer_lifetime_value  income  total_claim_amount
# 0  BU79786                  2763.52   56274              384.81
# 1  QZ44356                  6979.54       0             1131.46
# 2  AI49188                 12887.43   48767              566.47
# 3  WW63253                  7645.86       0              529.88
# 4  HB64268                  2813.69   43836              138.13

# %% [markdown]
# ### Cleaning discrete values

# %%
# Cleaning 'policy_type' --> Removing word 'Auto'
discrete_df['policy_type'] = discrete_df['policy_type'].str.replace('Auto','')

# %%
# Cleaning 'policy' --> Removing everything before the 'L'
discrete_df['policy'] = discrete_df['policy'].str.replace(".*(?=\d)", "", regex = True)

# %%
# Adapting 'policy'': converting 1, 2 and 3 into C, B, A
def cleanPolicy(x):
    #x = x.lower()
    if x == 1:
        return 'C'
    elif x == 2:
        return 'B'
    else:
        return 'A'

discrete_df['policy'] = list(map(cleanPolicy, discrete_df['policy']))

# %%
# Adapting 'vehicle_class': grouping all luxury cars together
def cleanVehicleClass(x):
    #x = x.lower()
    if 'Two-Door Car' in x:
        return 'Two-Door Car'
    elif 'Four-Door Car' in x:
        return 'Four-Door Car'
    elif 'SUV' in x:
        return 'SUV'
    else:
        return 'Luxury'

discrete_df['vehicle_class'] = list(map(cleanVehicleClass, discrete_df['vehicle_class']))

# %%
# Adapting 'education': ranked
def cleanEducation(x):
    #x = x.lower()
    if 'High School or Below' in x:
        return 1
    elif 'Bachelor' in x:
        return 2
    elif 'College' in x:
        return 3   
    elif 'Master' in x:
        return 4
    else:
        return 5

discrete_df['education'] = list(map(cleanEducation, discrete_df['education']))

# %%
# Adapting 'employmentstatus': grouping disabled, medical leave and retired into one category. 
def cleanEmployment(x):
    if 'Employed' in x:
        return 'employed'
    elif 'Unemployed' in x:
        return 'unemployed'
    else:
        return 'other'

discrete_df['employmentstatus'] = list(map(cleanEmployment, discrete_df['employmentstatus']))

# %%
# Binning 'effective_to_date'. Months are Jan & Feb, so grouping in segments of 2 weeks. 
# cut in 4 equally spaced bins
labels = ["Jan1", "Jan2", "Feb1", "Feb2"]
bins = pd.cut(discrete_df['effective_to_date'],4, labels=labels)
discrete_df['effective_to_date'] = pd.cut(discrete_df['effective_to_date'], 4, labels = labels)
bins.value_counts()
# Out:
# Jan2    2426
# Jan1    2294
# Feb2    2274
# Feb1    2140
# Name: effective_to_date, dtype: int64

# %%
# NOTE: this step I'm doing here corresponds to one of the forthcoming questions. 
# However, as it's part of the data preparation, I feel more comfortable doing it here.

discrete_df["coverage"] = discrete_df["coverage"].map({"Basic" : 0, "Extended" : 1, "Premium" : 2})
discrete_df["employmentstatus"] = discrete_df["employmentstatus"].map({"unemployed" : 0, "employed" : 1, "other" : 2})
discrete_df["location_code"] = discrete_df["location_code"].map({"Rural" : 0, "Suburban" : 1, "Urban" : 2})
discrete_df["vehicle_size"] = discrete_df["vehicle_size"].map({"Small" : 0, "Medsize" : 1, "Large" : 2})

# %%
# Outcome after all transformations
discrete_df.head()
# Out:
#         state response  coverage  education effective_to_date  \
# 0  Washington       No         0          2              Feb2
# 1     Arizona       No         1          2              Feb1
# 2      Nevada       No         2          2              Feb2
# 3  California       No         0          2              Jan2
# 4  Washington       No         0          2              Feb1
#
#    employmentstatus gender  location_code marital_status  \
# 0                 1      F              1        Married
# 1                 0      F              1         Single
# 2                 1      F              1        Married
# 3                 0      M              1        Married
# 4                 1      M              0         Single
#
#    monthly_premium_auto  months_since_last_claim  \
# 0                    69                       32
# 1                    94                       13
# 2                   108                       18
# 3                   106                       18
# 4                    73                       12
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    number_of_policies policy_type policy renew_offer_type sales_channel  \
# 0                   1  Corporate       A           Offer1         Agent
# 1                   8   Personal       A           Offer3         Agent
# 2                   2   Personal       A           Offer1         Agent
# 3                   7  Corporate       A           Offer1   Call Center
# 4                   1   Personal       A           Offer1         Agent
#
#    vehicle_class  vehicle_size
# 0   Two-Door Car             1
# 1  Four-Door Car             1
# 2   Two-Door Car             1
# 3            SUV             1
# 4  Four-Door Car             1

# %% [markdown]
# ### Cleaning continuous variables

# %%
# Dropping column 'customer'
continuous_df = continuous_df.drop(['customer'], axis = 1)
continuous_df.head()
# Out:
#    customer_lifetime_value  income  total_claim_amount
# 0                  2763.52   56274              384.81
# 1                  6979.54       0             1131.46
# 2                 12887.43   48767              566.47
# 3                  7645.86       0              529.88
# 4                  2813.69   43836              138.13

# %% [markdown]
# ### 1. Checking for outliers in continuous variables.

# %%
def cont_plot(col):
    
    for col in continuous_df.columns:
        sns.boxplot(x=continuous_df[col])
        plt.show()
    
cont_plot(continuous_df.columns)

# %%
# Upper and lower limits for customer_lifetime_value (1,5*iqr)
iqr = np.percentile(continuous_df['customer_lifetime_value'],75) - np.percentile(continuous_df['customer_lifetime_value'],25)
upper_limit = np.percentile(continuous_df['customer_lifetime_value'],75) + 1.5*iqr
lower_limit = np.percentile(continuous_df['customer_lifetime_value'],25) - 1.5*iqr
print('upper_limit for customer_lifetime_value is:', upper_limit)
print('lower_limit for customer_lifetime_value is:', lower_limit)
# Out:
# upper_limit for customer_lifetime_value is: 16414.039911750002
# lower_limit for customer_lifetime_value is: -3457.6210762500014

# %%
# Upper and lower limits for total_claim_amount (1,5*iqr)
iqr = np.percentile(continuous_df['total_claim_amount'],75) - np.percentile(continuous_df['total_claim_amount'],25)
upper_limit = np.percentile(continuous_df['total_claim_amount'],75) + 1.5*iqr
lower_limit = np.percentile(continuous_df['total_claim_amount'],25) - 1.5*iqr
print('upper_limit for total_claim_amount is:', upper_limit)
print('lower_limit for total_claim_amount is:', lower_limit)
# Out:
# upper_limit for total_claim_amount is: 960.3997301249999
# lower_limit for total_claim_amount is: -140.62664687499995

# %%
# COMMENT: 
# There seem to be too many outliers for continuous variables in this particular dataset. I will be keeping them.

# %% [markdown]
# ### 2. Create a copy of the dataframe for the data wrangling.

# %%
data = pd.concat((continuous_df, discrete_df), axis = 1)
data
# Out:
#       customer_lifetime_value  income  total_claim_amount       state  \
# 0                     2763.52   56274              384.81  Washington
# 1                     6979.54       0             1131.46     Arizona
# 2                    12887.43   48767              566.47      Nevada
# 3                     7645.86       0              529.88  California
# 4                     2813.69   43836              138.13  Washington
# ...                       ...     ...                 ...         ...
# 9129                 23405.99   71941              198.23  California
# 9130                  3096.51   21604              379.20  California
# 9131                  8163.89       0              790.78  California
# 9132                  7524.44   21941              691.20  California
# 9133                  2611.84       0              369.60  California
#
#      response  coverage  education effective_to_date  employmentstatus gender  \
# 0          No         0          2              Feb2                 1      F
# 1          No         1          2              Feb1                 0      F
# 2          No         2          2              Feb2                 1      F
# 3          No         0          2              Jan2                 0      M
# 4          No         0          2              Feb1                 1      M
# ...       ...       ...        ...               ...               ...    ...
# 9129       No         0          2              Feb1                 1      M
# 9130      Yes         1          3              Feb1                 1      F
# 9131       No         1          2              Feb1                 0      M
# 9132       No         1          3              Feb1                 1      M
# 9133       No         1          3              Feb2                 0      M
#
#       location_code marital_status  monthly_premium_auto  \
# 0                 1        Married                    69
# 1                 1         Single                    94
# 2                 1        Married                   108
# 3                 1        Married                   106
# 4                 0         Single                    73
# ...             ...            ...                   ...
# 9129              2        Married                    73
# 9130              1       Divorced                    79
# 9131              1         Single                    85
# 9132              1        Married                    96
# 9133              1         Single                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies policy_type policy  \
# 0                             0                   1  Corporate       A
# 1                             0                   8   Personal       A
# 2                             0                   2   Personal       A
# 3                             0                   7  Corporate       A
# 4                             0                   1   Personal       A
# ...                         ...                 ...         ...    ...
# 9129                          0                   2   Personal       A
# 9130                          0                   1  Corporate       A
# 9131                          3                   2  Corporate       A
# 9132                          0                   3   Personal       A
# 9133                          0                   1  Corporate       A
#
#      renew_offer_type sales_channel  vehicle_class  vehicle_size
# 0              Offer1         Agent   Two-Door Car             1
# 1              Offer3         Agent  Four-Door Car             1
# 2              Offer1         Agent   Two-Door Car             1
# 3              Offer1   Call Center            SUV             1
# 4              Offer1         Agent  Four-Door Car             1
# ...               ...           ...            ...           ...
# 9129           Offer2           Web  Four-Door Car             1
# 9130           Offer1        Branch  Four-Door Car             1
# 9131           Offer1        Branch  Four-Door Car             1
# 9132           Offer3        Branch  Four-Door Car             2
# 9133           Offer4   Call Center   Two-Door Car             1
#
# [9134 rows x 23 columns]

# %% [markdown]
# ### 3. Normalizing/scaling variables

# %% [markdown]
# #### Xy split

# %%
# Before normalizing/scaling, we must do our Xy split. 
# I considered using customer_lifetime_value as the target, but the results in the regression model were quite poor. 
# I finally decided to go for total_claim_amount to see the differences. 

y = data['total_claim_amount']
X = data.drop(['total_claim_amount'], axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

# %%
display(X_train.shape)
display(y_train.shape)
display(X_test.shape)
display(y_test.shape)
# Out:
# (7307, 22)
# (7307,)
# (1827, 22)
# (1827,)

# %% [markdown]
# #### Normalizing numericals

# %%
# Train set
X_train_num = X_train.select_dtypes(include = np.number)
transformer = MinMaxScaler().fit(X_train_num)
X_train_num_norm = transformer.transform(X_train_num)
X_train_num_norm = pd.DataFrame(X_train_num_norm, columns=X_train_num.columns)
X_train_num_norm
# Out:
#       customer_lifetime_value  income  coverage  education  employmentstatus  \
# 0                        0.21    0.23      0.00       0.50              0.50
# 1                        0.01    0.21      0.00       0.25              1.00
# 2                        0.01    0.00      0.00       0.00              0.00
# 3                        0.13    0.00      0.00       0.00              0.00
# 4                        0.07    0.26      0.00       0.00              1.00
# ...                       ...     ...       ...        ...               ...
# 7302                     0.33    0.21      1.00       0.50              1.00
# 7303                     0.04    0.99      0.50       0.25              0.50
# 7304                     0.16    0.00      0.50       0.25              0.00
# 7305                     0.08    0.20      0.00       0.00              1.00
# 7306                     0.06    0.25      0.50       0.25              1.00
#
#       location_code  monthly_premium_auto  months_since_last_claim  \
# 0              1.00                  0.04                     0.31
# 1              0.50                  0.00                     0.94
# 2              0.50                  0.05                     0.20
# 3              0.50                  0.24                     0.43
# 4              0.50                  0.02                     0.31
# ...             ...                   ...                      ...
# 7302           0.50                  0.57                     0.17
# 7303           0.00                  0.27                     0.20
# 7304           0.50                  0.33                     0.14
# 7305           0.50                  0.24                     0.49
# 7306           0.50                  0.11                     0.51
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                              0.69                       0.00
# 1                              0.62                       0.00
# 2                              0.78                       0.00
# 3                              0.69                       0.00
# 4                              0.39                       0.00
# ...                             ...                        ...
# 7302                           0.47                       0.00
# 7303                           0.36                       0.20
# 7304                           0.57                       0.00
# 7305                           0.41                       0.20
# 7306                           0.08                       0.00
#
#       number_of_policies  vehicle_size
# 0                   0.12          0.50
# 1                   0.00          0.50
# 2                   0.00          0.00
# 3                   0.12          0.50
# 4                   0.12          0.00
# ...                  ...           ...
# 7302                0.12          0.00
# 7303                0.00          0.50
# 7304                0.12          0.50
# 7305                1.00          0.50
# 7306                1.00          0.50
#
# [7307 rows x 12 columns]

# %%
# Test set
X_test_num = X_test.select_dtypes(include = np.number)
X_test_num_norm = transformer.transform(X_test_num)
X_test_num_norm = pd.DataFrame(X_test_num_norm, columns=X_test_num.columns)
X_test_num_norm
# Out:
#       customer_lifetime_value  income  coverage  education  employmentstatus  \
# 0                        0.09    0.28      0.00       0.00              0.50
# 1                        0.01    0.47      0.00       0.25              0.50
# 2                        0.03    0.37      0.00       0.25              0.50
# 3                        0.01    0.18      0.00       0.50              1.00
# 4                        0.03    0.00      0.00       0.50              0.00
# ...                       ...     ...       ...        ...               ...
# 1822                     0.04    0.31      0.00       0.50              0.50
# 1823                     0.07    0.55      0.50       0.50              0.50
# 1824                     0.01    0.72      0.00       0.00              0.50
# 1825                     0.02    0.68      0.50       0.25              0.50
# 1826                     0.01    0.82      0.00       0.25              0.50
#
#       location_code  monthly_premium_auto  months_since_last_claim  \
# 0              0.50                  0.22                     0.17
# 1              0.50                  0.02                     0.17
# 2              0.50                  0.19                     0.37
# 3              0.50                  0.04                     0.83
# 4              0.50                  0.03                     0.20
# ...             ...                   ...                      ...
# 1822           0.00                  0.00                     0.23
# 1823           0.00                  0.15                     0.14
# 1824           1.00                  0.05                     0.69
# 1825           0.00                  0.11                     0.69
# 1826           1.00                  0.02                     0.09
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                              0.27                       0.00
# 1                              0.35                       0.00
# 2                              0.18                       0.20
# 3                              0.71                       0.00
# 4                              0.76                       0.00
# ...                             ...                        ...
# 1822                           0.36                       0.00
# 1823                           0.11                       0.60
# 1824                           0.59                       0.00
# 1825                           0.54                       0.00
# 1826                           0.46                       0.00
#
#       number_of_policies  vehicle_size
# 0                   0.25          0.50
# 1                   0.00          0.00
# 2                   0.00          0.50
# 3                   0.00          0.50
# 4                   0.50          0.50
# ...                  ...           ...
# 1822                0.62          0.50
# 1823                1.00          0.50
# 1824                0.00          0.50
# 1825                0.00          0.50
# 1826                0.00          0.00
#
# [1827 rows x 12 columns]

# %% [markdown]
# #### One Hot Encoding categoricals

# %%
# Train set

# %%
X_train_cat = X_train.select_dtypes(object)

encoder = OneHotEncoder(drop='first').fit(X_train_cat)
encoded = encoder.transform(X_train_cat).toarray()
cols = encoder.get_feature_names_out(input_features=X_train_cat.columns)
X_train_cat_norm = onehot_encoded = pd.DataFrame(encoded, columns=cols)

# %%
# Test set

# %%
X_test_cat = X_test.select_dtypes(object)

encoded = encoder.transform(X_test_cat).toarray()
cols = encoder.get_feature_names_out(input_features=X_test_cat.columns)
X_test_cat_norm = onehot_encoded = pd.DataFrame(encoded, columns=cols)

# %% [markdown]
# #### Concatenating DataFrames

# %%
X_train_scaled = pd.concat((X_train_num_norm, X_train_cat_norm), axis = 1)
X_test_scaled = pd.concat((X_test_num_norm, X_test_cat_norm), axis = 1)
display(X_train_scaled.head(2))
display(X_test_scaled.head(2))
# Out:
#    customer_lifetime_value  income  coverage  education  employmentstatus  \
# 0                     0.21    0.23      0.00       0.50              0.50
# 1                     0.01    0.21      0.00       0.25              1.00
#
#    location_code  monthly_premium_auto  months_since_last_claim  \
# 0           1.00                  0.04                     0.31
# 1           0.50                  0.00                     0.94
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                           0.69                       0.00
# 1                           0.62                       0.00
#
#    number_of_policies  vehicle_size  state_California  state_Nevada  \
# 0                0.12          0.50              0.00          0.00
# 1                0.00          0.50              0.00          0.00
#
#    state_Oregon  state_Washington  response_Yes  gender_M  \
# 0          1.00              0.00          0.00      0.00
# 1          0.00              0.00          0.00      1.00
#
#    marital_status_Married  marital_status_Single  policy_type_Personal   \
# 0                    1.00                   0.00                   1.00
# 1                    1.00                   0.00                   1.00
#
#    policy_type_Special   renew_offer_type_Offer2  renew_offer_type_Offer3  \
# 0                  0.00                     1.00                     0.00
# 1                  0.00                     1.00                     0.00
#
#    renew_offer_type_Offer4  sales_channel_Branch  sales_channel_Call Center  \
# 0                     0.00                  0.00                       0.00
# 1                     0.00                  0.00                       0.00
#
#    sales_channel_Web  vehicle_class_Luxury  vehicle_class_SUV  \
# 0               0.00                  0.00               0.00
# 1               0.00                  0.00               0.00
#
#    vehicle_class_Two-Door Car
# 0                        0.00
# 1                        0.00
#    customer_lifetime_value  income  coverage  education  employmentstatus  \
# 0                     0.09    0.28      0.00       0.00              0.50
# 1                     0.01    0.47      0.00       0.25              0.50
#
#    location_code  monthly_premium_auto  months_since_last_claim  \
# 0           0.50                  0.22                     0.17
# 1           0.50                  0.02                     0.17
#
#    months_since_policy_inception  number_of_open_complaints  \
# 0                           0.27                       0.00
# 1                           0.35                       0.00
#
#    number_of_policies  vehicle_size  state_California  state_Nevada  \
# 0                0.25          0.50              1.00          0.00
# 1                0.00          0.00              1.00          0.00
#
#    state_Oregon  state_Washington  response_Yes  gender_M  \
# 0          0.00              0.00          0.00      0.00
# 1          0.00              0.00          0.00      1.00
#
#    marital_status_Married  marital_status_Single  policy_type_Personal   \
# 0                    1.00                   0.00                   1.00
# 1                    1.00                   0.00                   1.00
#
#    policy_type_Special   renew_offer_type_Offer2  renew_offer_type_Offer3  \
# 0                  0.00                     0.00                     0.00
# 1                  0.00                     1.00                     0.00
#
#    renew_offer_type_Offer4  sales_channel_Branch  sales_channel_Call Center  \
# 0                     1.00                  0.00                       0.00
# 1                     0.00                  0.00                       1.00
#
#    sales_channel_Web  vehicle_class_Luxury  vehicle_class_SUV  \
# 0               0.00                  1.00               0.00
# 1               0.00                  0.00               0.00
#
#    vehicle_class_Two-Door Car
# 0                        0.00
# 1                        0.00

# %% [markdown]
# #### y_train & y_test index reset

# %%
# This step is needed because during the transformation process of X_train_scaled the index has been reset.
# We then need to reset the index for y_train & y_test to make them match.

y_train = y_train.reset_index(drop=True) 
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# # Models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### LinearRegression

# %%
lm = linear_model.LinearRegression()
lm.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
predictions = lm.predict(X_train_scaled)
print('R2 score for the training set is:', r2_score(y_train, predictions))
# Out:
# R2 score for the training set is: 0.6154763739600597

# %%
predictions_test = lm.predict(X_test_scaled)
print('R2 score for the test set is:', r2_score(y_test, predictions_test))
# Out:
# R2 score for the test set is: 0.6417177599083381

# %% [markdown]
# ### KNeighborsRegressor

# %%
KNN = KNeighborsRegressor(n_neighbors=6, algorithm = 'brute')
KNN.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(algorithm='brute', n_neighbors=6)

# %%
score = KNN.score(X_test_scaled, y_test)
score
# Out:
# 0.46234041111102697

# %%
score_train = KNN.score(X_train_scaled, y_train)
score_train
# Out:
# 0.6246016034036457
