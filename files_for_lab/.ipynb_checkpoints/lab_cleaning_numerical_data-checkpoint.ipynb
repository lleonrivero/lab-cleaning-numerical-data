# %% [markdown]
# # LAB 1 - CLEANING NUMERICAL DATA

# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
display(customer_df.head(2))
display(customer_df.tail(2))
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# ...

# %% [markdown]
# ### 3. Look at the main features (head, shape, info).

# %%
#customer_df.shape
#customer_df.dtypes
customer_df.isna().sum()
customer_df.isna().sum()/len(customer_df)*100
customer_df.describe().T
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# ### 4. Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)

# %%
cols = []
for i in range(len(customer_df.columns)):
    cols.append(customer_df.columns[i].lower().replace(' ', '_'))
customer_df.columns = cols

# %%
#customer_df = customer_df.rename(columns = {'employmentstatus' : 'employment_status'})

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# ### 5. Change effective to date column to datetime format.

# %%
customer_df['effective_to_date'] = pd.to_datetime(customer_df['effective_to_date'], errors='coerce')

# %% [markdown]
# ### 6. Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful. Store continuous data into a continuous_df variable and do the same for discrete_df

# %%
# Checking the variability of values in the dataset.
    # High values mean more variability.
    # Lower values mean less variability.
# We will use these percentages to define whether the variable will be considered
# continuous or discrete.

customer_df.nunique()/len(customer_df)*100
# Out:
# customer                         100.000000
# state                              0.054741
# customer_lifetime_value           88.033720
# response                           0.021896
# coverage                           0.032844
# education                          0.054741
# effective_to_date                  0.645938
# employmentstatus                   0.054741
# gender                             0.021896
# income                            62.338515
# location_code                      0.032844
# marital_status                     0.032844
# monthly_premium_auto               2.211517
# months_since_last_claim            0.394132
# months_since_policy_inception      1.094811
# number_of_open_complaints          0.065689
# number_of_policies                 0.098533
# policy_type                        0.032844
# policy                             0.098533
# renew_offer_type                   0.043792
# sales_channel                      0.043792
# ...

# %%
customer_df.shape[0] * 0.01 
customer_df.nunique()/len(customer_df)*100
customer_df.nunique()
# Out:
# customer                         9134
# state                               5
# customer_lifetime_value          8041
# response                            2
# coverage                            3
# education                           5
# effective_to_date                  59
# employmentstatus                    5
# gender                              2
# income                           5694
# location_code                       3
# marital_status                      3
# monthly_premium_auto              202
# months_since_last_claim            36
# months_since_policy_inception     100
# number_of_open_complaints           6
# number_of_policies                  9
# policy_type                         3
# policy                              9
# renew_offer_type                    4
# sales_channel                       4
# total_claim_amount               5106
# vehicle_class                       6
# vehicle_size                        3
# dtype: int64

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
# Maria and Fernando have helped me to understand how to define this function: all the credit to them. 

def cont_disc(DataFrame):
    continuous = []
    discrete = []

    threshold = customer_df.shape[0] * 0.01 

    for x in customer_df.columns:    # df.index for rows
        if customer_df[x].nunique() < threshold:
            discrete.append(x)
        else:
            continuous.append(x)
    return discrete, continuous

discrete, continuous = cont_disc(customer_df)

# %%
discrete_df = customer_df[discrete]
discrete_df
# Out:
#            state response  coverage education effective_to_date  \
# 0     Washington       No     Basic  Bachelor        2011-02-24
# 1        Arizona       No  Extended  Bachelor        2011-01-31
# 2         Nevada       No   Premium  Bachelor        2011-02-19
# 3     California       No     Basic  Bachelor        2011-01-20
# 4     Washington       No     Basic  Bachelor        2011-02-03
# ...          ...      ...       ...       ...               ...
# 9129  California       No     Basic  Bachelor        2011-02-10
# 9130  California      Yes  Extended   College        2011-02-12
# 9131  California       No  Extended  Bachelor        2011-02-06
# 9132  California       No  Extended   College        2011-02-03
# 9133  California       No  Extended   College        2011-02-14
#
#      employmentstatus gender location_code marital_status  \
# 0            Employed      F      Suburban        Married
# 1          Unemployed      F      Suburban         Single
# ...

# %%
continuous_df = customer_df[continuous]
continuous_df
# Out:
#      customer  customer_lifetime_value  income  monthly_premium_auto  \
# 0     BU79786              2763.519279   56274                    69
# 1     QZ44356              6979.535903       0                    94
# 2     AI49188             12887.431650   48767                   108
# 3     WW63253              7645.861827       0                   106
# 4     HB64268              2813.692575   43836                    73
# ...       ...                      ...     ...                   ...
# 9129  LA72316             23405.987980   71941                    73
# 9130  PK87824              3096.511217   21604                    79
# 9131  TD14365              8163.890428       0                    85
# 9132  UP19263              7524.442436   21941                    96
# 9133  Y167826              2611.836866       0                    77
#
#       months_since_policy_inception  total_claim_amount
# 0                                 5          384.811147
# ...

# %% [markdown]
# ### 7. Plot a correlation matrix, comment what you see.

# %%
# No strong correlations revealed, although there seems to be a certain positive correlation
# between total_claim_amount and monthly_premium_auto. 

fig, ax=plt.subplots(figsize=(20,16))

correlations_matrix = continuous_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %% [markdown]
# ### 8. Create a function to plot every discrete variable. Do the same with the continuous variables (Be Careful, you may need to change the plot type to one better suited for continuous data!)

# %%
def disc_plot(i):
    
    for i in discrete_df.columns:
        sns.boxplot(x=i, y=continuous_df['total_claim_amount'], data=discrete_df)
        plt.show()
    
disc_plot(i)

# %%
# Seen in class
def plot_cat(i):
    
    for i in discrete_df.columns:
        sns.countplot(x=discrete_df[i])
        plt.show()
    
plot_cat(i)

# %%
def cont_plot(i): # It has taken a long time to run
    
    for i in continuous_df.columns:
        sns.displot(continuous_df[i], kde = True)
        plt.show()

cont_plot(i)

# %% [markdown]
# ### 9. Comment what you can see in the plots.

# %%
# Note: I'm trying to run the plots for continuous variables, but they won't open or will only open after a long time. 
# I'm having to stop the execution of the cell.

# %% [markdown]
# ### 10. Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)

# %%
def outliers(i):
    
    for i in continuous_df:
        sns.boxplot(x=i, y=continuous_df['total_claim_amount'], data=continuous_df)
        plt.show()
    
outliers(i)

# %% [markdown]
# ### 11. Did you find outliers? Comment what you will do with them.

# %%
# Note: I'm trying to run the plots for continuous variables, but they won't open or will only open after a long time. 
# I'm having to stop the execution of the cell.

# %% [markdown]
# ### 12. Check all columns for NaN values. Decide what (if anything) you will need to do with them.

# %%
# No NaN values detected

customer_df.isna().sum()/len(customer_df)*100
# Out:
# customer                         0.0
# state                            0.0
# customer_lifetime_value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective_to_date                0.0
# employmentstatus                 0.0
# gender                           0.0
# income                           0.0
# location_code                    0.0
# marital_status                   0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# policy_type                      0.0
# policy                           0.0
# renew_offer_type                 0.0
# sales_channel                    0.0
# total_claim_amount               0.0
# vehicle_class                    0.0
# vehicle_size                     0.0
# dtype: float64
